# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone --recurse-submodules https://github.com/wadi-sudo/tracking1.git  # clone repo
# %cd tracking1
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.10.0+cu111 (Tesla K80)

# %% [markdown]
# # Download data
#
# Get test video from repo and extract the first 2 seconds of it

# %%
# get yolov5m model trained on the crowd-human dataset
# !wget -nc https://github.com/mikel-brostrom/Yolov5_DeepSort_Pytorch/releases/download/v.2.0/crowdhuman_yolov5m.pt -O /content/Yolov5_DeepSort_Pytorch/yolov5/weights/crowdhuman_yolov5m.pt

# get the test video from the repo
# !wget -nc https://github.com/mikel-brostrom/Yolov5_DeepSort_Pytorch/releases/download/v.2.0/test.avi
# extract 3 seconds worth of video frames of it
# !y | ffmpeg -ss 00:00:00 -i test.avi -t 00:00:02 -c copy out.avi

# %% [markdown]
# ## Run inference on video
#
# The ``cv2.imshow()`` and ``cv.imshow()`` functions from the [opencv-python](https://github.com/skvark/opencv-python) package are incompatible with Jupyter notebook; see https://github.com/jupyter/notebook/issues/3935.
#
# Hence we chose to save it to file in this notebook. Locally you can use the ``--show-vid`` flag in order visualize the tracking in real-time

# %%
# !python track.py --yolo_model /content/tracking1/best.pt --deep_sort_model=shufflenet --source test.mp4  --save-vid --save-txt
# Out:
# deep_sort/deep/reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '
# YOLOv5 🚀 2022-3-18 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# deep_sort/deep/reid/torchreid/models/shufflenet.py:196: UserWarning: The imagenet pretrained weights need to be manually downloaded from https://mega.nz/#!RDpUlQCY!tr_5xBEkelzDjveIYBBcGcovNCOrgfiJO9kiidz9fZM
#   .format(model_urls['imagenet'])
# Model: shufflenet
# - params: 904,728
# - flops: 89,143,296
# YOLOv5 🚀 2022-3-18 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 224 layers, 7078183 parameters, 0 gradients
# video 1/1 (1/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (2/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.027s)
# video 1/1 (3/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (4/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.019s)
# video 1/1 (5/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (6/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (7/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (8/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (9/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.023s)
# video 1/1 (10/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (11/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (12/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (13/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.026s)
# video 1/1 (14/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (15/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (16/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (17/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (18/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (19/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (20/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (21/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (22/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (23/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (24/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (25/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (26/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (27/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (28/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (29/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (30/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (31/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (32/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (33/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (34/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (35/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (36/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (37/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.019s)
# video 1/1 (38/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (39/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.031s), DeepSort:(0.018s)
# video 1/1 (40/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (41/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (42/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (43/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (44/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (45/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (46/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (47/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (48/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (49/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (50/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (51/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (52/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (53/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (54/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (55/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (56/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (57/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (58/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (59/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (60/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.028s), DeepSort:(0.015s)
# video 1/1 (61/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (62/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (63/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (64/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (65/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (66/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (67/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (68/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (69/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (70/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (71/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (72/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (73/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (74/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (75/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (76/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (77/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (78/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (79/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (80/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (81/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (82/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (83/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (84/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (85/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (86/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (87/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (88/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (89/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (90/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (91/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (92/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.033s), DeepSort:(0.015s)
# video 1/1 (93/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (94/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (95/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.022s)
# video 1/1 (96/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.023s)
# video 1/1 (97/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (98/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (99/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (100/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (101/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (102/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (103/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (104/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (105/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (106/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (107/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (108/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (109/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (110/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (111/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (112/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (113/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (114/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (115/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (116/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# No detections
# No detections
# video 1/1 (119/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (120/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (121/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (122/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (123/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (124/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (125/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (126/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (127/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (128/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (129/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (130/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (131/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# No detections
# No detections
# No detections
# No detections
# video 1/1 (136/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (137/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (138/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (139/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (140/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (141/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (142/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.030s), DeepSort:(0.017s)
# video 1/1 (143/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (144/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (145/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (146/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (147/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (148/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (149/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (150/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (151/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (152/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (153/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (154/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (155/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (156/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.028s), DeepSort:(0.015s)
# video 1/1 (157/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (158/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (159/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (160/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (161/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 2 DJI-Phantoms, Done. YOLO:(0.029s), DeepSort:(0.022s)
# video 1/1 (162/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (163/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (164/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (165/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (166/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.028s), DeepSort:(0.015s)
# No detections
# No detections
# video 1/1 (169/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (170/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (171/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (172/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.030s), DeepSort:(0.015s)
# video 1/1 (173/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (174/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (175/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (176/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (177/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (178/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.028s), DeepSort:(0.016s)
# video 1/1 (179/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (180/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (181/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (182/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (183/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (184/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (185/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (186/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (187/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (188/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# No detections
# video 1/1 (190/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (191/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (192/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (193/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (194/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (195/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (196/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (197/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (198/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (199/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (200/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (201/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (202/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (203/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (204/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (205/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (206/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (207/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (208/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (209/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.022s)
# video 1/1 (210/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (211/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (212/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (213/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (214/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (215/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (216/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (217/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (218/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (219/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (220/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (221/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (222/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (223/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (224/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (225/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (226/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (227/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (228/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (229/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (230/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (231/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (232/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (233/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (234/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (235/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (236/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (237/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (238/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (239/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (240/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (241/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (242/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (243/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (244/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (245/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (246/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (247/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (248/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (249/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (250/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (251/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (252/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.019s)
# video 1/1 (253/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (254/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (255/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (256/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (257/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.026s)
# video 1/1 (258/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (259/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (260/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (261/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (262/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (263/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (264/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (265/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (266/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (267/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.019s)
# video 1/1 (268/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (269/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (270/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (271/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (272/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (273/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (274/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (275/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (276/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (277/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (278/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (279/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (280/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (281/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (282/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (283/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (284/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (285/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (286/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (287/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (288/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (289/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (290/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (291/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (292/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (293/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (294/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (295/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (296/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.019s)
# video 1/1 (297/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (298/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (299/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (300/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (301/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (302/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (303/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (304/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (305/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (306/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (307/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (308/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.028s), DeepSort:(0.017s)
# video 1/1 (309/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (310/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (311/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (312/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (313/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (314/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (315/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (316/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (317/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (318/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (319/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# No detections
# No detections
# video 1/1 (322/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (323/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (324/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (325/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (326/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (327/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (328/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (329/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (330/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (331/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.023s)
# video 1/1 (332/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (333/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (334/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# ...
# No detections
# No detections
# video 1/1 (718/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (719/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (720/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (721/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (722/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (723/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (724/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (725/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (726/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (727/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (728/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (729/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (730/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (731/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (732/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (733/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (734/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (735/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (736/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.019s)
# video 1/1 (737/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# No detections
# video 1/1 (739/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (740/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (741/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (742/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (743/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (744/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (745/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (746/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (747/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (748/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (749/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (750/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.019s)
# video 1/1 (751/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (752/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (753/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (754/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (755/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (764/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (765/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (766/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# No detections
# video 1/1 (768/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (769/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (770/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (771/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (772/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (773/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (774/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (775/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.019s)
# video 1/1 (776/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (777/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (778/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (779/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (780/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (781/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (782/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (783/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (784/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (785/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (786/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (787/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (788/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (789/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (790/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (791/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (792/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (793/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (794/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (795/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# No detections
# No detections
# video 1/1 (798/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (799/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (800/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (801/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (802/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (810/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# No detections
# No detections
# video 1/1 (813/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (814/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.021s)
# video 1/1 (815/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (816/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (817/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (818/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (819/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (820/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (821/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (822/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (823/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.020s)
# video 1/1 (824/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (825/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.026s)
# video 1/1 (826/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (827/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.019s)
# video 1/1 (828/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (829/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (830/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-mavic, 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.017s)
# video 1/1 (831/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (832/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (839/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (840/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (841/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (842/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (843/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# No detections
# No detections
# video 1/1 (846/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (847/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.016s)
# video 1/1 (848/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# video 1/1 (849/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.018s)
# video 1/1 (850/850) /content/drive/MyDrive/Colab Notebooks/test/tracking1/test.mp4: 384x640 1 DJI-Phantom, Done. YOLO:(0.029s), DeepSort:(0.015s)
# Speed: 0.5ms pre-process, 29.0ms inference, 1.3ms NMS, 13.8ms deep sort update         per image at shape (1, 3, 640, 640)
# Results saved to runs/track/exp/test.mp4

# %%
# %cd '/content/drive/My Drive/Colab Notebooks/test/'
# Out:
# /content/drive/My Drive/Colab Notebooks/test

# %%
# !python track.py --yolo_model best1.pt --deep_sort_model=shufflenet --source test.mp4  --save-vid --save-txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Show results
#
# https://stackoverflow.com/questions/60977179/how-to-play-avi-file-in-google-colab
#
# Convert avi to mp4

# %%
# !ffmpeg -i /content/Yolov5_DeepSort_Pytorch/runs/track/exp/out.avi output.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, avi, from '/content/Yolov5_DeepSort_Pytorch/inference/output/out.avi':
#   Metadata:
#     encoder         : Lavf58.35.100
#   Duration: 00:00:01.00, start: 0.000000, bitrate: 13681 kb/s
#     Stream #0:0: Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 960x540 [SAR 1:1 DAR 16:9], 13850 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56258d48de00] using SAR=1/1
# [libx264 @ 0x56258d48de00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56258d48de00] profile High, level 3.2
# [libx264 @ 0x56258d48de00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 960x540 [SAR 1:1 DAR 16:9], q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   60 fps= 38 q=-1.0 Lsize=     333kB time=00:00:00.95 bitrate=2874.0kbits/s speed=0.606x
# video:332kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.455911%
# [libx264 @ 0x56258d48de00] frame I:1     Avg QP:24.03  size: 32488
# [libx264 @ 0x56258d48de00] frame P:19    Avg QP:25.74  size: 11462
# [libx264 @ 0x56258d48de00] frame B:40    Avg QP:31.19  size:  2220
# [libx264 @ 0x56258d48de00] consecutive B-frames:  8.3%  6.7%  5.0% 80.0%
# [libx264 @ 0x56258d48de00] mb I  I16..4: 15.0% 78.4%  6.6%
# [libx264 @ 0x56258d48de00] mb P  I16..4:  2.2%  7.0%  2.8%  P16..4: 30.5% 10.5%  8.0%  0.0%  0.0%    skip:39.0%
# [libx264 @ 0x56258d48de00] mb B  I16..4:  0.3%  0.5%  0.1%  B16..8: 28.8%  4.9%  1.5%  direct: 1.0%  skip:62.9%  L0:57.5% L1:38.4% BI: 4.2%
# [libx264 @ 0x56258d48de00] 8x8 transform intra:63.8% inter:64.3%
# [libx264 @ 0x56258d48de00] coded y,uvDC,uvAC intra: 57.4% 64.0% 22.1% inter: 6.5% 12.1% 5.2%
# [libx264 @ 0x56258d48de00] i16 v,h,dc,p: 40% 32% 23%  5%
# [libx264 @ 0x56258d48de00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 25% 39%  3%  2%  2%  1%  2%  3%
# [libx264 @ 0x56258d48de00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 45% 19% 12%  4%  3%  4%  4%  5%  4%
# [libx264 @ 0x56258d48de00] i8c dc,h,v,p: 38% 26% 34%  2%
# [libx264 @ 0x56258d48de00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56258d48de00] ref P L0: 66.1%  9.6% 15.4%  8.9%
# [libx264 @ 0x56258d48de00] ref B L0: 85.0% 12.5%  2.6%
# [libx264 @ 0x56258d48de00] ref B L1: 96.3%  3.7%
# [libx264 @ 0x56258d48de00] kb/s:2712.56

# %% [markdown]
# Get the file content into data_url

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/tracking1/runs/track/exp/anka.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %% [markdown]
# Display it with HTML

# %%
HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
